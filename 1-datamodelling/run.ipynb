# %%
# !bash run.sh
# Out:
# Dropped sparkifydb
# Created sparkifydb
# Executed DROP TABLE IF EXISTS songplays
# Executed DROP TABLE IF EXISTS users
# Executed DROP TABLE IF EXISTS songs
# Executed DROP TABLE IF EXISTS artists
# Executed DROP TABLE IF EXISTS time
# Executed CREATE TABLE IF NOT EXISTS songplays (songplay_id varchar, start_time int, user_id int, level varchar, song_id varchar, artist_id varchar, session_id int, location varchar, user_agent varchar);
# Executed CREATE TABLE IF NOT EXISTS users (user_id int, first_name varchar, last_name varchar, gender varchar, level varchar);
# Executed CREATE TABLE IF NOT EXISTS songs (song_id varchar, title varchar, artist_id varchar, year int, duration int);
# Executed CREATE TABLE IF NOT EXISTS artists (artist_id varchar, name varchar, location varchar, latitude int, longitude int);
# Executed CREATE TABLE IF NOT EXISTS time (start_time timestamp, hour int, day int, week int, month int, year int, weekday int);
# 71 files found in data/song_data
# ...

# %%
# !python create_tables.py
# Out:
# Traceback (most recent call last):
#   File "create_tables.py", line 75, in <module>
#     main()
#   File "create_tables.py", line 66, in main
#     cur, conn = create_database()
#   File "create_tables.py", line 12, in create_database
#     conn = psycopg2.connect("dbname=studentdb user=student password=student")
#   File "C:\Users\mvcollignon\AppData\Local\Continuum\anaconda3\lib\site-packages\psycopg2\__init__.py", line 126, in connect
#     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
# psycopg2.OperationalError: could not connect to server: Connection refused (0x0000274D/10061)
# 	Is the server running on host "localhost" (::1) and accepting
# 	TCP/IP connections on port 5432?
# could not connect to server: Connection refused (0x0000274D/10061)
# 	Is the server running on host "localhost" (127.0.0.1) and accepting
# 	TCP/IP connections on port 5432?
